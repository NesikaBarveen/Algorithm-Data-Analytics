# %% [markdown]
# TITANIC DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.size
# Out:
# 13365

# %%
titanic.ndim
# Out:
# 2

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].isnull().sum()
# Out:
# np.int64(177)

# %%
titanic['age']=titanic['age'].fillna(titanic['age'].mode()[0])

# %%
titanic['age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,cmap='plasma')
plt.title('correlation heatmap')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True),cmap='plasma')
plt.title('correlation heatmap')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,cmap='viridis')
plt.title('correlation heatmap')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,cmap='magma')
plt.title('correlation heatmap')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,cmap='Blues')
plt.title('correlation heatmap')
plt.show()

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,cmap='twilight')
plt.title('correlation heatmap')
plt.show()

# %%
sns.scatterplot(x=titanic['age'],y=titanic['survived'])
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.scatterplot(x='age',y='survived',data=titanic,alpha=0.6,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.stripplot(x='age',y='survived',data=titanic,jitter=True,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.swarmplot(x='survived',y='age',data=titanic,hue='sex',dodge=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 21.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='survived', ylabel='age'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 23.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='survived',y='age',data=titanic,hue='sex',dodge=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='survived', ylabel='age'>
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 27.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.hist(titanic['age'],bins=40)
plt.title("HISTOGRAM")
plt.legend()
plt.show()
# Out:
# <ipython-input-41-e4f4e76f2006>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.hist(titanic['age'].dropna(),bins=50,color='skyblue',edgecolor='black',label='Age')
plt.title("HISTOGRAM OF PASSANGER AGES")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
sns.countplot(titanic['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
titanic['survived'].value_counts().plot.pie(autopct='%1.1f%%',colors=['lightcoral','lightgreen'])
plt.title("Survival distribution")
plt.ylabel('')
plt.show()

# %%
titanic['sex'].value_counts().plot.pie(autopct='%1.1f%%',colors=['red','yellow'])
plt.title("Gender distribution")
plt.ylabel('')
plt.show()

# %%
sns.boxplot(x=titanic['age'],color='pink')
plt.xlabel("age")
plt.title("Box Plot of Passenger Ages")
plt.show()

# %%
sns.boxplot(x='survived',y='age',data=titanic,palette='Set2')
plt.title("Age Distribution by Survival")
plt.xlabel("Survived(0=No,1=Yes)")
plt.ylabel("Age")
plt.show()
# Out:
# <ipython-input-62-e3572a90cace>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='survived',y='age',data=titanic,palette='Set2')

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#        Geography     Sales Person               Product   Amount  Units
# 0             UK       Ram Mahesh    Manuka Honey Choco       $0    135
# 1             UK  Gunar Cockshoot       Mint Chip Choco      $21    168
# 2    New Zealand      Brien Boise        70% Dark Bites      $42    150
# 3      Australia     Barr Faughny             Milk Bars      $56     51
# 4      Australia       Oby Sorrel             Milk Bars      $63    123
# ..           ...              ...                   ...      ...    ...
# 295           UK       Oby Sorrel   Peanut Butter Cubes  $12,950     30
# 296          USA     Gigi Bohling       Raspberry Choco  $13,391    201
# 297        India     Husein Augar  Caramel Stuffed Bars  $14,329    150
# 298        India     Gigi Bohling          Orange Choco  $15,610    339
# 299       Canada     Gigi Bohling       Mint Chip Choco  $16,184     39
#
# [300 rows x 5 columns]

# %%
game=pd.read_csv('game_dataset.csv')
# Out:
#      Game_ID       Game_Name      Genre     Platform  Release_Year  \
# 0      G0001  Warrior Galaxy  Adventure       Switch          2002
# 1      G0002    Legend Quest     Action       Mobile          2019
# 2      G0003   Empire Battle  Adventure  PlayStation          2016
# 3      G0004     Shadow Rise   Strategy  PlayStation          2019
# 4      G0005     Quest Arena  Adventure       Switch          2020
# ...      ...             ...        ...          ...           ...
# 1995   G1996     Battle Fury        RPG         Xbox          2017
# 1996   G1997   Battle Battle  Adventure         Xbox          2017
# 1997   G1998      Quest Fury     Racing           PC          2016
# 1998   G1999  Empire Warrior        RPG  PlayStation          2017
# 1999   G2000     Legend Fury  Adventure         Xbox          2004
#
#       Global_Sales  User_Rating  Active_Players
# 0            28.62          4.8            95.7
# 1            24.17          5.4            50.9
# ...
